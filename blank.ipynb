# %%
pip install opencv-python-headless==4.5.5.62
# Out:
# Collecting opencv-python-headless==4.5.5.62
#   Downloading opencv_python_headless-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.7 MB)
#      |████████████████████████████████| 47.7 MB 46.7 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from opencv-python-headless==4.5.5.62) (1.21.6)
# Installing collected packages: opencv-python-headless
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.1.2.30
#     Uninstalling opencv-python-headless-4.1.2.30:
#       Successfully uninstalled opencv-python-headless-4.1.2.30
# Successfully installed opencv-python-headless-4.5.5.62
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv
print( cv.__version__ )
# Out:
# 4.5.5

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /srv/conda/envs/notebook/lib/python3.7/site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.14.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from opencv-python) (1.21.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Определяем красный картинка
import cv2
import numpy as np

img=cv2.imread('rose.jpg')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
 

rl=np.array([136,87,111],np.uint8)
ru=np.array([180,255,255],np.uint8)

red=cv2.inRange(hsv, rl, ru)

kernal = np.ones((5 ,5), "uint8")

red=cv2.dilate(red, kernal)
res=cv2.bitwise_and(img, img, mask = red)

contours,hierarchy=cv2.findContours(red,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

for pic, contour in enumerate(contours):
    area = cv2.contourArea(contour)
    if(area>300):

        x,y,w,h = cv2.boundingRect(contour)
        img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,255),2)
        cv2.putText(img,"RED ",(x,y),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255))


isWritten = cv2.imwrite('image1.png', img)

if isWritten:
    print('Image is successfully saved as file.')
# Out:
# Image is successfully saved as file.

# %%
pip uninstall opencv-python-headless==4.5.5.62
# Out:
# Found existing installation: opencv-python-headless 4.1.2.30
# Uninstalling opencv-python-headless-4.1.2.30:
#   Would remove:
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/*
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/opencv_python_headless-4.1.2.30.dist-info/*
#   Would not remove (might be manually added):
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/config-3.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/config.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/cv2.abi3.so
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/gapi/__init__.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/load_config_py2.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/load_config_py3.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/mat_wrapper/__init__.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/misc/__init__.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/misc/version.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSans-Bold.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSans-BoldOblique.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSans-ExtraLight.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSans-Oblique.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSans.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSansCondensed-Bold.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSansCondensed-BoldOblique.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSansCondensed-Oblique.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/fonts/DejaVuSansCondensed.ttf
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/qt/plugins/platforms/libqxcb.so
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/utils/__init__.py
#     /srv/conda/envs/notebook/lib/python3.7/site-packages/cv2/version.py
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.
